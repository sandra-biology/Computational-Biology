# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.linspace(0, 10, 100)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x))

# fig1, ax1 = plt.subplots()
# ax.plot(x, np.cos(x))

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.linspace(0, 10, 100)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), x, np.cos(x))

# fig1, ax1 = plt.subplots()
# ax.plot(x, np.cos(x))
# Out:
# [<matplotlib.lines.Line2D at 0x23366d12668>,
#  <matplotlib.lines.Line2D at 0x23368d3ff60>]

# %%
fig, ax = plt.subplots(2)
_ = ax[0].plot(x, np.sin(x))
_ = ax[1].plot(x, np.cos(x))

# %%
fig, ax = plt.subplots()
ax.plot(x, np.sin(x - 0), color="blue")
ax.plot(x, np.sin(x - 1), color="g")
ax.plot(x, np.sin(x - 2), color="0.75")  # grayscale between 0 and 1
ax.plot(x, np.sin(x - 3), color="#FFDD44")  # HEX code between 00 and FF
ax.plot(x, np.sin(x - 4), color=(1.0, 0.2, 0.3))  #RGB tuple, values 0 and 1
ax.plot(x, np.sin(x - 5), color="chartreuse")  # all HTML color names supported

# %%
fig, ax = plt.subplots()
_ = ax.plot(x, np.sin(x))
_ = ax.set_xlim(-1, 11)
_ = ax.set_ylim(-1.5, 1.5)

# %%
fig, ax = plt.subplots()
_ = ax.plot(x, np.sin(x))
_ = ax.set_xlim(10, 0)
_ = ax.set_ylim(1.2, -1.2)

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

fig, ax = plt.subplots()
_ = ax.plot(x, y, "o", color="black")

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

fig, ax = plt.subplots(1,3)
_ = ax[0].hist(x1)
_ = ax[1].hist(x2)
_ = ax[2].hist(x3)

# %%
fig, ax = plt.subplots(2, 3, sharex="col", sharey="row")
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)), fontsize=18, ha="center")

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection="3d")

zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
_ = ax.plot3D(xline, yline, zline, "gray")

zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
_ = ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap="Greens")
