# %%
# ar1[0..m-1] and ar2[0..n-1] are two
# given sorted arrays and x is given
# number. This function prints the pair
# from both arrays such that the sum
# of the pair is closest to x.
def printClosest(ar1, ar2, m, n, x):
 
    # Initialize the diff between
    # pair sum and x.
    diff=1e6
 
    # res_l and res_r are result
    # indexes from ar1[] and ar2[]
    # respectively. Start from left
    # side of ar1[] and right side of ar2[]
    l = 0
    r = n-1
    while(l < m and r >= 0):
     
    # If this pair is closer to x than
    # the previously found closest,
    # then update res_l, res_r and diff
        if abs(ar1[l] + ar2[r] - x) < diff:
            res_l = l
            res_r = r
            diff = abs(ar1[l] + ar2[r] - x)
     
 
    # If sum of this pair is more than x,
    # move to smaller side
        if ar1[l] + ar2[r] > x:
            r=r-1
        else: # move to the greater side
            l=l+1
     
 
    # return the result
    return  ar1[res_l], ar2[res_r]
 
ar1 = [1, 4, 5, 7]
ar2 = [10, 20, 30, 40]
m = len(ar1)
n = len(ar2)
x = 38
x = 51
printClosest(ar1, ar2, m, n, x)
# Out:
# (7, 40)

# %%
import numpy as np

def find_closest(metas_sort, adducts_sort, x):
    # initialize the delta as sum of first element of each array
    left_min = -1
    right_min = -1
    delta_min = metas_sort[left_min] + adducts_sort[right_min]
 
    # left_min and right_min are indexes from metas_sort and adducts_sort respectively
    left = 0
    right = len(adducts_sort) - 1
    while left < len(metas_sort) and right >= 0:
        sum_curr = metas_sort[left] + adducts_sort[right]
        delta_curr = abs(sum_curr - x)
        
        if delta_curr < delta_min:  # current sum is closest to x: update left_min, right_min, and delta_min
            left_min = left
            right_min = right
            delta_min = delta_curr

        if sum_curr > x:  # current sum is too large: decrement right index
            right -= 1
        else:  # current sum is too small: increment left index
            left += 1
         
    return  left_min, right_min

metas = [0.000003, 0.000012, 0.000081, 0.000099, 0.000076, 0.000045, 0.000092, 0.000068, 0.000047] 
adducts = [0.000002, 0.000045, -0.000063, -0.000009, -0.000050, 0.000048, 0.000070, -0.000037, 0.000056, -0.000008]
signals = [0.000079, 0.000094, 0.000084, 0.000052, 0.000064, 0.000055, 0.000070, 0.000079]
adducts_ind = np.argsort(adducts)
adducts_sort = [adducts[adducts_ind[i]] for i in range(len(adducts))]
print(f'adducts_sort: {adducts_sort}')
metas_ind = np.argsort(metas)
metas_sort = [metas[metas_ind[i]] for i in range(len(metas))]
print(f'metas_sort: {metas_sort}')
indices = find_closest(metas_sort, adducts_sort, signals[0])
print(f'signals[0] indices: {indices}')
indices = find_closest(metas_sort, adducts_sort, signals[7])
print(f'signals[7] indices: {indices}')
indices = find_closest(metas_sort, adducts_sort, signals[4])
print(f'signals[4] indices: {indices}')
# Out:
# adducts_sort: [-6.3e-05, -5e-05, -3.7e-05, -9e-06, -8e-06, 2e-06, 4.5e-05, 4.8e-05, 5.6e-05, 7e-05]
# metas_sort: [3e-06, 1.2e-05, 4.5e-05, 4.7e-05, 6.8e-05, 7.6e-05, 8.1e-05, 9.2e-05, 9.9e-05]
# signals[0] indices: (5, 5)
# signals[7] indices: (5, 5)
# signals[4] indices: (8, 2)

# %%
# annotate funciton without writing to output file

import numpy as np

def find_closest(metas_sort, adducts_sort, x):
    i_pairs = []
    
    # initialize the delta as sum of first element of metas_sort and last element of adducts_sort
    for i in range(len(x)):
        left_min = -1
        right_min = -1
        delta_min = metas_sort[left_min] + adducts_sort[right_min]

        # left_min and right_min are indices from metas_sort and adducts_sort respectively
        left = 0
        right = len(adducts_sort) - 1
        while left < len(metas_sort) and right >= 0:
            sum_curr = metas_sort[left] + adducts_sort[right]
            delta_curr = abs(sum_curr - x[i])

            if delta_curr <= delta_min:
                left_min = left
                right_min = right
                delta_min = delta_curr

            if sum_curr > x[i]:  # current sum is too large: decrement right index
                right -= 1
            else:  # current sum is too small: increment left index
                left += 1

        i_pairs.append((left_min, right_min))

    return  i_pairs

def annotate_sorted_metas_adducts(input_name):
    input_file = open(input_name)
    n_tests = int(input_file.readline().strip())
    
    for itest in range(n_tests):

        int_numbers = input_file.readline().strip()
        nmeta, nadduct, nsignals = [int(x) for x in int_numbers.split()]

        metas = [float(x) for x in input_file.readline().strip().split()]
        adducts = [float(x) for x in input_file.readline().strip().split()]
        signals = [float(x) for x in input_file.readline().strip().split()]
        
        metas_ind = np.argsort(metas)
        metas_sort = [metas[metas_ind[i]] for i in range(len(metas))]
        adducts_ind = np.argsort(adducts)
        adducts_sort = [adducts[adducts_ind[i]] for i in range(len(adducts))]
        
        list_pairs = find_closest(metas_sort, adducts_sort, signals)
    
    return list_pairs
    input_file.close()

input_name = '1.txt'
annotate_sorted_metas_adducts(input_name)
# Out:
# x[0]: 7.9e-05
# x[1]: 9.4e-05
# x[2]: 8.4e-05
# x[3]: 5.2e-05
# x[4]: 6.4e-05
# x[5]: 5.5e-05
# x[6]: 7e-05
# x[7]: 7.9e-05
# [(5, 5), (7, 5), (7, 4), (0, 7), (8, 2), (7, 2), (4, 5), (5, 5)]

# %%
# annotate funciton: going from sorted indices to original indices

import numpy as np

def find_closest(metas_sort, adducts_sort, x):
    i_pairs = []
    
    # initialize the delta as sum of first element of metas_sort and last element of adducts_sort
    for i in range(len(x)):
        left_min = -1
        right_min = -1
        delta_min = metas_sort[left_min] + adducts_sort[right_min]

        # left_min and right_min are indices from metas_sort and adducts_sort respectively
        left = 0
        right = len(adducts_sort) - 1
        while left < len(metas_sort) and right >= 0:
            sum_curr = metas_sort[left] + adducts_sort[right]
            delta_curr = abs(sum_curr - x[i])

            if delta_curr <= delta_min:
                left_min = left
                right_min = right
                delta_min = delta_curr

            if sum_curr > x[i]:  # current sum is too large: decrement right index
                right -= 1
            else:  # current sum is too small: increment left index
                left += 1

        i_pairs.append((left_min, right_min))

    return  i_pairs

def annotate_sorted_metas_adducts(input_name):
    input_file = open(input_name)
    n_tests = int(input_file.readline().strip())
    indices = []
    for itest in range(n_tests):

        int_numbers = input_file.readline().strip()
        nmeta, nadduct, nsignals = [int(x) for x in int_numbers.split()]

        metas = [float(x) for x in input_file.readline().strip().split()]
        adducts = [float(x) for x in input_file.readline().strip().split()]
        signals = [float(x) for x in input_file.readline().strip().split()]
        
        metas_ind = np.argsort(metas)
        metas_sort = [metas[metas_ind[i]] for i in range(len(metas))]
        adducts_ind = np.argsort(adducts)
        adducts_sort = [adducts[adducts_ind[i]] for i in range(len(adducts))]
        
        list_pairs = find_closest(metas_sort, adducts_sort, signals)
        for x in list_pairs:
            imeta = metas_ind[x[0]]
            iadduct = adducts_ind[x[1]]
            indices.append((imeta, iadduct))
    
    return indices
    input_file.close()

input_name = '1.txt'
output_name = input_name[:-4] + '_output_geeks_algorithm.txt'
annotate_sorted_metas_adducts(input_name)
# Out:
# [(4, 0), (6, 0), (6, 9), (0, 5), (3, 7), (6, 7), (7, 0), (4, 0)]

# %%
# annotate funciton writes indices to output file

import numpy as np

def find_closest(metas_sort, adducts_sort, x):
    i_pairs = []
    
    # initialize the delta as sum of first element of metas_sort and last element of adducts_sort
    for i in range(len(x)):
        left_min = -1
        right_min = -1
        delta_min = metas_sort[left_min] + adducts_sort[right_min]

        # left_min and right_min are indices from metas_sort and adducts_sort respectively
        left = 0
        right = len(adducts_sort) - 1
        while left < len(metas_sort) and right >= 0:
            sum_curr = metas_sort[left] + adducts_sort[right]
            delta_curr = abs(sum_curr - x[i])

            if delta_curr <= delta_min:
                left_min = left
                right_min = right
                delta_min = delta_curr

            if sum_curr > x[i]:  # current sum is too large: decrement right index
                right -= 1
            else:  # current sum is too small: increment left index
                left += 1

        i_pairs.append((left_min, right_min))

    return  i_pairs

def annotate_sorted_metas_adducts(input_name, output_name):
    input_file = open(input_name)
    output_file = open(output_name, 'w')
    n_tests = int(input_file.readline().strip())
    indices = []
    for itest in range(n_tests):

        int_numbers = input_file.readline().strip()
        nmeta, nadduct, nsignals = [int(x) for x in int_numbers.split()]

        metas = [float(x) for x in input_file.readline().strip().split()]
        adducts = [float(x) for x in input_file.readline().strip().split()]
        signals = [float(x) for x in input_file.readline().strip().split()]
        
        metas_ind = np.argsort(metas)
        metas_sort = [metas[metas_ind[i]] for i in range(len(metas))]
        adducts_ind = np.argsort(adducts)
        adducts_sort = [adducts[adducts_ind[i]] for i in range(len(adducts))]
        
        list_pairs = find_closest(metas_sort, adducts_sort, signals)
        for x in list_pairs:
            imeta = metas_ind[x[0]]
            iadduct = adducts_ind[x[1]]
            output_file.write(f'{imeta+1} {iadduct+1}\n')
    
    print(f'created output_file {output_name}')
    input_file.close()
    output_file.close()

input_name = '1.txt'
output_name = input_name[:-4] + '_output_geeks_algorithm.txt'
annotate_sorted_metas_adducts(input_name, output_name)
# Out:
# created output_file 1_output_geeks_algorithm.txt

# %%
# solution: file 2.txt

import numpy as np

def find_closest(metas_sort, adducts_sort, x):
    i_pairs = []
    
    # initialize the delta as sum of first element of metas_sort and last element of adducts_sort
    for i in range(len(x)):
        left_min = -1
        right_min = -1
        delta_min = metas_sort[left_min] + adducts_sort[right_min]

        # left_min and right_min are indices from metas_sort and adducts_sort respectively
        left = 0
        right = len(adducts_sort) - 1
        while left < len(metas_sort) and right >= 0:
            sum_curr = metas_sort[left] + adducts_sort[right]
            delta_curr = abs(sum_curr - x[i])

            if delta_curr <= delta_min:
                left_min = left
                right_min = right
                delta_min = delta_curr

            if sum_curr > x[i]:  # current sum is too large: decrement right index
                right -= 1
            else:  # current sum is too small: increment left index
                left += 1

        i_pairs.append((left_min, right_min))

    return  i_pairs

def annotate_sorted_metas_adducts(input_name, output_name):
    input_file = open(input_name)
    output_file = open(output_name, 'w')
    n_tests = int(input_file.readline().strip())
    indices = []
    for itest in range(n_tests):

        int_numbers = input_file.readline().strip()
        nmeta, nadduct, nsignals = [int(x) for x in int_numbers.split()]

        metas = [float(x) for x in input_file.readline().strip().split()]
        adducts = [float(x) for x in input_file.readline().strip().split()]
        signals = [float(x) for x in input_file.readline().strip().split()]
        
        metas_ind = np.argsort(metas)
        metas_sort = [metas[metas_ind[i]] for i in range(len(metas))]
        adducts_ind = np.argsort(adducts)
        adducts_sort = [adducts[adducts_ind[i]] for i in range(len(adducts))]
        
        list_pairs = find_closest(metas_sort, adducts_sort, signals)
        for x in list_pairs:
            imeta = metas_ind[x[0]]
            iadduct = adducts_ind[x[1]]
            output_file.write(f'{imeta+1} {iadduct+1}\n')
    
    print(f'created output_file {output_name}')
    input_file.close()
    output_file.close()

input_name = '2.txt'
output_name = input_name[:-4] + '_output_geeks_algorithm.txt'
annotate_sorted_metas_adducts(input_name, output_name)
# Out:
# created output_file 2_output_geeks_algorithm.txt

# %%
# solution: file 3.txt

import numpy as np

def find_closest(metas_sort, adducts_sort, x):
    i_pairs = []
    
    # initialize the delta as sum of first element of metas_sort and last element of adducts_sort
    for i in range(len(x)):
        if i % 1000 == 0:
            print(f'processing i: {i}')
        left_min = -1
        right_min = -1
        delta_min = metas_sort[left_min] + adducts_sort[right_min]

        # left_min and right_min are indices from metas_sort and adducts_sort respectively
        left = 0
        right = len(adducts_sort) - 1
        while left < len(metas_sort) and right >= 0:
            sum_curr = metas_sort[left] + adducts_sort[right]
            delta_curr = abs(sum_curr - x[i])

            if delta_curr <= delta_min:
                left_min = left
                right_min = right
                delta_min = delta_curr

            if sum_curr > x[i]:  # current sum is too large: decrement right index
                right -= 1
            else:  # current sum is too small: increment left index
                left += 1

        i_pairs.append((left_min, right_min))

    return  i_pairs

def annotate_sorted_metas_adducts(input_name, output_name):
    input_file = open(input_name)
    output_file = open(output_name, 'w')
    n_tests = int(input_file.readline().strip())
    indices = []
    for itest in range(n_tests):

        int_numbers = input_file.readline().strip()
        nmeta, nadduct, nsignals = [int(x) for x in int_numbers.split()]

        metas = [float(x) for x in input_file.readline().strip().split()]
        adducts = [float(x) for x in input_file.readline().strip().split()]
        signals = [float(x) for x in input_file.readline().strip().split()]
        
        metas_ind = np.argsort(metas)
        metas_sort = [metas[metas_ind[i]] for i in range(len(metas))]
        adducts_ind = np.argsort(adducts)
        adducts_sort = [adducts[adducts_ind[i]] for i in range(len(adducts))]
        
        list_pairs = find_closest(metas_sort, adducts_sort, signals)
        for x in list_pairs:
            imeta = metas_ind[x[0]]
            iadduct = adducts_ind[x[1]]
            output_file.write(f'{imeta+1} {iadduct+1}\n')
    
    print(f'created output_file {output_name}')
    input_file.close()
    output_file.close()

input_name = '3.txt'
output_name = input_name[:-4] + '_output_geeks_algorithm.txt'
# annotate_sorted_metas_adducts(input_name, output_name)

# %%
# solution: file 4.txt

import numpy as np

def find_closest(metas_sort, adducts_sort, x):
    i_pairs = []
    
    # initialize the delta as sum of first element of metas_sort and last element of adducts_sort
    for i in range(len(x)):
        if metas_sort[i] % 10000 == 0:
            print(f'processing metas_sort[i]: {metas_sort[i]}')
        left_min = -1
        right_min = -1
        delta_min = metas_sort[left_min] + adducts_sort[right_min]

        # left_min and right_min are indices from metas_sort and adducts_sort respectively
        left = 0
        right = len(adducts_sort) - 1
        while left < len(metas_sort) and right >= 0:
            sum_curr = metas_sort[left] + adducts_sort[right]
            delta_curr = abs(sum_curr - x[i])

            if delta_curr <= delta_min:
                left_min = left
                right_min = right
                delta_min = delta_curr

            if sum_curr > x[i]:  # current sum is too large: decrement right index
                right -= 1
            else:  # current sum is too small: increment left index
                left += 1

        i_pairs.append((left_min, right_min))

    return  i_pairs

def annotate_sorted_metas_adducts(input_name, output_name):
    input_file = open(input_name)
    output_file = open(output_name, 'w')
    n_tests = int(input_file.readline().strip())
    indices = []
    for itest in range(n_tests):

        int_numbers = input_file.readline().strip()
        nmeta, nadduct, nsignals = [int(x) for x in int_numbers.split()]

        metas = [float(x) for x in input_file.readline().strip().split()]
        adducts = [float(x) for x in input_file.readline().strip().split()]
        signals = [float(x) for x in input_file.readline().strip().split()]
        
        metas_ind = np.argsort(metas)
        metas_sort = [metas[metas_ind[i]] for i in range(len(metas))]
        adducts_ind = np.argsort(adducts)
        adducts_sort = [adducts[adducts_ind[i]] for i in range(len(adducts))]
        
        list_pairs = find_closest(metas_sort, adducts_sort, signals)
        for x in list_pairs:
            imeta = metas_ind[x[0]]
            iadduct = adducts_ind[x[1]]
            output_file.write(f'{imeta+1} {iadduct+1}\n')
    
    print(f'created output_file {output_name}')
    input_file.close()
    output_file.close()

input_name = '4.txt'
output_name = input_name[:-4] + '_output_geeks_algorithm.txt'
annotate_sorted_metas_adducts(input_name, output_name)

# %%
# %%timeit

# solution: file 4.txt

import numpy as np

def find_closest(metas_sort, adducts_sort, x):
    i_pairs = []
    
    # initialize the delta as sum of first element of metas_sort and last element of adducts_sort
    for i in range(len(x)):
        if metas_sort[i] % 10000 == 0:
            print(f'processing metas_sort[i]: {metas_sort[i]}')
        left_min = -1
        right_min = -1
        delta_min = metas_sort[left_min] + adducts_sort[right_min]

        # left_min and right_min are indices from metas_sort and adducts_sort respectively
        left = 0
        right = len(adducts_sort) - 1
        while left < len(metas_sort) and right >= 0:
            sum_curr = metas_sort[left] + adducts_sort[right]
            delta_curr = abs(sum_curr - x[i])

            if delta_curr <= delta_min:
                left_min = left
                right_min = right
                delta_min = delta_curr

            if sum_curr > x[i]:  # current sum is too large: decrement right index
                right -= 1
            else:  # current sum is too small: increment left index
                left += 1

        i_pairs.append((left_min, right_min))

    return  i_pairs

def annotate_sorted_metas_adducts(input_name, output_name):
    input_file = open(input_name)
    output_file = open(output_name, 'w')
    n_tests = int(input_file.readline().strip())
    indices = []
    for itest in range(n_tests):

        int_numbers = input_file.readline().strip()
        nmeta, nadduct, nsignals = [int(x) for x in int_numbers.split()]

        metas = [float(x) for x in input_file.readline().strip().split()]
        adducts = [float(x) for x in input_file.readline().strip().split()]
        signals = [float(x) for x in input_file.readline().strip().split()]
        
        metas_ind = np.argsort(metas)
        metas_sort = [metas[metas_ind[i]] for i in range(len(metas))]
        adducts_ind = np.argsort(adducts)
        adducts_sort = [adducts[adducts_ind[i]] for i in range(len(adducts))]
        
        list_pairs = find_closest(metas_sort, adducts_sort, signals)
        for x in list_pairs:
            imeta = metas_ind[x[0]]
            iadduct = adducts_ind[x[1]]
            output_file.write(f'{imeta+1} {iadduct+1}\n')
    
    print(f'created output_file {output_name}')
    input_file.close()
    output_file.close()

input_name = '4.txt'
output_name = input_name[:-4] + '_output_geeks_algorithm.txt'
annotate_sorted_metas_adducts(input_name, output_name)
# Out:
# created output_file 4_output_geeks_algorithm.txt
# created output_file 4_output_geeks_algorithm.txt
# created output_file 4_output_geeks_algorithm.txt
# created output_file 4_output_geeks_algorithm.txt
# created output_file 4_output_geeks_algorithm.txt
# created output_file 4_output_geeks_algorithm.txt
# created output_file 4_output_geeks_algorithm.txt
# created output_file 4_output_geeks_algorithm.txt
# 46min 37s ± 3.08 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# solution: file 5.txt

import numpy as np

def find_closest(metas_sort, adducts_sort, x):
    i_pairs = []
    
    # initialize the delta as sum of first element of metas_sort and last element of adducts_sort
    for i in range(len(x)):
        if metas_sort[i] % 10000 == 0:
            print(f'processing metas_sort[i]: {metas_sort[i]}')
        left_min = -1
        right_min = -1
        delta_min = metas_sort[left_min] + adducts_sort[right_min]

        # left_min and right_min are indices from metas_sort and adducts_sort respectively
        left = 0
        right = len(adducts_sort) - 1
        while left < len(metas_sort) and right >= 0:
            sum_curr = metas_sort[left] + adducts_sort[right]
            delta_curr = abs(sum_curr - x[i])

            if delta_curr <= delta_min:
                left_min = left
                right_min = right
                delta_min = delta_curr

            if sum_curr > x[i]:  # current sum is too large: decrement right index
                right -= 1
            else:  # current sum is too small: increment left index
                left += 1

        i_pairs.append((left_min, right_min))

    return  i_pairs

def annotate_sorted_metas_adducts(input_name, output_name):
    input_file = open(input_name)
    output_file = open(output_name, 'w')
    n_tests = int(input_file.readline().strip())
    indices = []
    for itest in range(n_tests):

        int_numbers = input_file.readline().strip()
        nmeta, nadduct, nsignals = [int(x) for x in int_numbers.split()]

        metas = [float(x) for x in input_file.readline().strip().split()]
        adducts = [float(x) for x in input_file.readline().strip().split()]
        signals = [float(x) for x in input_file.readline().strip().split()]
        
        metas_ind = np.argsort(metas)
        metas_sort = [metas[metas_ind[i]] for i in range(len(metas))]
        adducts_ind = np.argsort(adducts)
        adducts_sort = [adducts[adducts_ind[i]] for i in range(len(adducts))]
        
        list_pairs = find_closest(metas_sort, adducts_sort, signals)
        for x in list_pairs:
            imeta = metas_ind[x[0]]
            iadduct = adducts_ind[x[1]]
            output_file.write(f'{imeta+1} {iadduct+1}\n')
    
    print(f'created output_file {output_name}')
    input_file.close()
    output_file.close()

input_name = '5.txt'
output_name = input_name[:-4] + '_output_geeks_algorithm.txt'
annotate_sorted_metas_adducts(input_name, output_name)
# Out:
# created output_file 5_output_geeks_algorithm.txt

# %%
metas = [0.000003, 0.000012, 0.000081, 0.000099, 0.000076, 0.000045, 0.000092, 0.000068, 0.000047] 
adducts = [0.000002, 0.000045, -0.000063, -0.000009, -0.000050, 0.000048, 0.000070, -0.000037, 0.000056, -0.000008]
signals = [0.000079, 0.000094, 0.000084, 0.000052, 0.000064, 0.000055, 0.000070, 0.000079]
metas_ind = np.argsort(metas)
adducts_ind = np.argsort(adducts)
signals_ind = np.argsort(signals)
print(f'metas_ind: {metas_ind}')
print(f'adducts_ind: {adducts_ind}')
print(f'adducts: {adducts}')
print(f'adducts_sort: {[adducts[adducts_ind[i]] for i in range(len(adducts))]}')

for i in range(len(adducts_ind)):
    print(f'sorted index: {i} original index: {adducts_ind[i]}')

list_pairs = [(5, 5), (7, 5), (7, 4), (0, 7), (8, 2), (7, 2), (4, 5), (5, 5)]
for x in list_pairs:
    print(f'original indices: {metas_ind[x[0]]} {adducts_ind[x[1]]}')
# Out:
# metas_ind: [0 1 5 8 7 4 2 6 3]
# adducts_ind: [2 4 7 3 9 0 1 5 8 6]
# adducts: [2e-06, 4.5e-05, -6.3e-05, -9e-06, -5e-05, 4.8e-05, 7e-05, -3.7e-05, 5.6e-05, -8e-06]
# adducts_sort: [-6.3e-05, -5e-05, -3.7e-05, -9e-06, -8e-06, 2e-06, 4.5e-05, 4.8e-05, 5.6e-05, 7e-05]
# sorted index: 0 original index: 2
# sorted index: 1 original index: 4
# sorted index: 2 original index: 7
# sorted index: 3 original index: 3
# sorted index: 4 original index: 9
# sorted index: 5 original index: 0
# sorted index: 6 original index: 1
# sorted index: 7 original index: 5
# sorted index: 8 original index: 8
# sorted index: 9 original index: 6
# original indices: 4 0
# original indices: 6 0
# original indices: 6 9
# original indices: 0 5
# original indices: 3 7
# original indices: 6 7
# original indices: 7 0
# original indices: 4 0
